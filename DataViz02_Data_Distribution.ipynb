# %% [markdown]
# <a href="https://colab.research.google.com/github/Jittiya/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')  # read csv สามารถอ่านไฟล์ที่อยู่ในอินเตอร์เน็ตได้เลย
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m k)

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %% [markdown]
# ## เพิ่มรายละเอียดราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])  # วาดกราฟ
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')  # วาดกราฟ พร้อมระบุชื่อกลุ่ม
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor') # วาดกราฟ พร้อมระบุชื่อกลุ่ม
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica') # วาดกราฟ พร้อมระบุชื่อกลุ่ม
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')  # วาดกราฟ พร้อมระบุชื่อกลุ่ม
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor') # วาดกราฟ พร้อมระบุชื่อกลุ่ม
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica') # วาดกราฟ พร้อมระบุชื่อกลุ่ม
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %% [markdown]
# ## ใช้ ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])  # กำหนดขนาด
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100]) # กำหนดขนาด
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica',s=df2['PetalWidth'][100:]) # กำหนดขนาด
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %% [markdown]
# ขยายขนาดของ marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])  # ขยายขนาดโดยการคูณ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100]) # ขยายขนาดโดยการคูณ
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica',s=40*df2['PetalWidth'][100:]) # ขยายขนาดโดยการคูณ
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %% [markdown]
# ## ปรับความโปร่งใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5 ,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])  # ปรับความโปรงแสง alpha
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5 ,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100]) # ปรับความโปรงแสง alpha
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5 ,c=df2['Name'][100:],label='virginica',s=40*df2['PetalWidth'][100:]) # ปรับความโปรงแสง alpha
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %% [markdown]
# ## เปลี่ยน marker ให้สวยงาม

# %% [markdown]
# https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5 ,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='P')  # เปลี่ยนรูปร่าง marker
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5 ,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='P') # เปลี่ยนรูปร่าง marker
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5 ,c=df2['Name'][100:],label='virginica',s=40*df2['PetalWidth'][100:],marker='P') # เปลี่ยนรูปร่าง marker
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$')  # เปลี่ยนรูปร่าง marker
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')  # เปลี่ยนรูปร่าง marker
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$g$')  # เปลี่ยนรูปร่าง marker
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2["PetalWidth"])

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')  #กำหนด plot แบบ 3 มิติ
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')  #กำหนด plot แบบ 3 มิติ
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')  #กำหนด plot แบบ 3 มิติ
plt.legend()
plt.xlabel('PetalLength')  # ชื่อแกน X
plt.ylabel('SepalLength') # ชื่อแกน Y
plt.title('comparing petal & sepal length of different iris flowers'); # ระบุชื่อกราฟ

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![111.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f36982c9050>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f36949329d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f369493aa10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f369493a4d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f369623d0d0>,
#   <matplotlib.lines.Line2D at 0x7f3694932490>]}

# %%
plt.boxplot(df['SepalLength'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f369623d990>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f36949242d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f369492c310>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3694924d90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f369491e810>,
#   <matplotlib.lines.Line2D at 0x7f369491ed50>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False)

# %% [markdown]
# กราฟแนวนอนใช้ get.xdata
#
# กราฟแนวตั้งใช้ get.ydata

# %% [markdown]
# medians

# %%
ybp['medians'][0].get_ydata()
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata()
# Out:
# array([5.8, 5.8])

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %% [markdown]
# min

# %%
min(ybp['whiskers'][0].get_xdata())
# Out:
# 4.3

# %% [markdown]
# max

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()
# Out:
# array([7.9, 7.9])

# %% [markdown]
# q1

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata())
# Out:
# 5.1

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3696221ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f369496ebd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f36948cf2d0>],
#  'means': [<matplotlib.lines.Line2D at 0x7f3694842e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f36948426d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f36961e4710>,
#   <matplotlib.lines.Line2D at 0x7f36961e4390>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanline=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f36948acd10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f369834e290>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f36982ed790>],
#  'means': [<matplotlib.lines.Line2D at 0x7f36982c9850>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f36982c9ad0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3698419950>,
#   <matplotlib.lines.Line2D at 0x7f369ffe8ad0>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3698480090>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f369847c2d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f36984db550>],
#  'means': [<matplotlib.lines.Line2D at 0x7f36984db790>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f36984dba90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f369851e150>,
#   <matplotlib.lines.Line2D at 0x7f369847ca10>]}

# %% [markdown]
# #Quiz กลุ่ม final
#
#
# 1.   เขียน function ที่รับ input เป็น output ของ boxplot แล้วแสดงค่า min, max, q1, q2, q3
# 2.   วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %% [markdown]
# ## 1.เขียน function ที่รับ input เป็น output ของ boxplot แล้วแสดงค่า min, max, q1, q2, q3

# %% [markdown]
# SepalLength

# %%
def box_vals(ybp):
    q1 = ybp['boxes'][0].get_xdata()[0]
    q2 = ybp['medians'][0].get_xdata()[0]
    q3 = ybp['boxes'][0].get_xdata()[2]
    iqr = q3-q1
    vmin = min(ybp['caps'][0].get_xdata())
    vmax = max(ybp['caps'][1].get_xdata())
    return  print(f'Q1 เท่ากับ {q1}\nQ2 เท่ากับ {q2}\nQ3 เท่ากับ {q3}\nIQR เท่ากับ {iqr}\nMin เท่ากับ {vmin}\nMax เท่ากับ {vmax}')

# %%
box_vals(ybp)
# Out:
# Q1 เท่ากับ 5.1
# Q2 เท่ากับ 5.8
# Q3 เท่ากับ 6.4
# IQR เท่ากับ 1.3000000000000007
# Min เท่ากับ 4.3
# Max เท่ากับ 7.9

# %% [markdown]
# SepalWidth

# %%
x = plt.boxplot(df['SepalWidth'],vert=False)

# %%
def box_vals(x):
    q1 = x['boxes'][0].get_xdata()[0]
    q2 = x['medians'][0].get_xdata()[0]
    q3 = x['boxes'][0].get_xdata()[2]
    iqr = q3-q1
    vmin = min(x['caps'][0].get_xdata())
    vmax = max(x['caps'][1].get_xdata())
    return  print(f'Q1 เท่ากับ {q1}\nQ2 เท่ากับ {q2}\nQ3 เท่ากับ {q3}\nIQR เท่ากับ {iqr}\nMin เท่ากับ {vmin}\nMax เท่ากับ {vmax}')

# %%
box_vals(x)
# Out:
# Q1 เท่ากับ 2.8
# Q2 เท่ากับ 3.0
# Q3 เท่ากับ 3.3
# IQR เท่ากับ 0.5
# Min เท่ากับ 2.2
# Max เท่ากับ 4.0

# %% [markdown]
# ##2.วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
plt.boxplot(df['PetalLength'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3698426dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f36987d6f50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f36986d8d10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3698740e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3698842e10>,
#   <matplotlib.lines.Line2D at 0x7f3698676350>]}

# %%
setsosabp = plt.boxplot(df2['PetalLength'][:50],vert=False)

# %%
versicolorbp = plt.boxplot(df2['PetalLength'][50:100],vert=False)

# %%
verginigabp = plt.boxplot(df2['PetalLength'][100:],vert=False)

# %%
setsosabp = plt.boxplot(df2['PetalLength'][:50],vert=False)
versicolorbp = plt.boxplot(df2['PetalLength'][50:100],vert=False)
verginigabp = plt.boxplot(df2['PetalLength'][100:],vert=False)

# %%
setsosabp = plt.boxplot(df2['PetalLength'][:50])
versicolorbp = plt.boxplot(df2['PetalLength'][50:100])
verginigabp = plt.boxplot(df2['PetalLength'][100:])

# %% [markdown]
# ## เฉลยของอาจารย์

# %% [markdown]
# ### ข้อ 1

# %%
bb = plt.boxplot(df['SepalLength'])

# %%
def detail_boxreturn(boxreturn):
      q1 = boxreturn['boxes'][0].get_ydata()[0]
      q2 = boxreturn['medians'][0].get_ydata()[0]
      q3 = boxreturn['boxes'][0].get_ydata()[2]
      minv = min(boxreturn['whiskers'][0].get_ydata())
      maxv = max(boxreturn['whiskers'][1].get_ydata())
      print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn(bb)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
bb2 = plt.boxplot(df['SepalLength'],vert=False)

# %%
detail_boxreturn(bb2)
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 0.925, q3 = 1.075

# %%
def detail_boxreturn_v2(boxreturn, vert=True):
    if vert == True:
        q1 = boxreturn['boxes'][0].get_ydata()[0]
        q2 = boxreturn['medians'][0].get_ydata()[0]
        q3 = boxreturn['boxes'][0].get_ydata()[2]
        minv = min(boxreturn['whiskers'][0].get_ydata())
        maxv = max(boxreturn['whiskers'][1].get_ydata())
    else:
        q1 = boxreturn['boxes'][0].get_xdata()[0]
        q2 = boxreturn['medians'][0].get_xdata()[0]
        q3 = boxreturn['boxes'][0].get_xdata()[2]
        minv = min(boxreturn['whiskers'][0].get_xdata())
        maxv = max(boxreturn['whiskers'][1].get_xdata())

    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn_v2(bb2)
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 0.925, q3 = 1.075

# %%
detail_boxreturn_v2(bb2,vert=False)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %% [markdown]
# ### ข้อ 2

# %%
plt.boxplot(df['SepalLength'][:50],positions = [1])
plt.boxplot(df['SepalLength'][50:100],positions = [2])
plt.boxplot(df['SepalLength'][100:150],positions = [3]);

# %% [markdown]
# # Violin plot

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.violinplot.html

# %%
bb = plt.boxplot(df['PetalLength'][:50])

# %%
plt.violinplot(df['PetalLength'][:50])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f36945d8a90>],
#  'cbars': <matplotlib.collections.LineCollection at 0x7f369452d810>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f36945d8750>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f36945d8190>}

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True)

# %% [markdown]
# ## HW ทดลอง plot ค่า quantile ลงไปในกราฟ (ศึกษาตัวแปล quantiles)

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True,quantiles=[0.25,0.5,0.75])
